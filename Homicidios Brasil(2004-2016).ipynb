# %% [markdown]
# ## Analise exploratoria dos dados: violencia do Brasil
# [dataset source](http://www.ipea.gov.br/atlasviolencia/dados-series/31)

# %% [markdown]
# o Estatuto do Desarmamento é uma lei federal derivada do projeto de lei nº 292 (PL 1555/2003), de autoria do então senador Gerson Camata (MDB/ES),[1] que entrou em vigor no dia seguinte à sanção do então presidente, Luiz Inácio Lula da Silva, no dia 23 de dezembro de 2003. Trata-se da Lei 10826 de 23 de dezembro de 2003, regulamentada pelo decreto 5123 de 1º de julho de 2004 e publicada no Diário Oficial da União no dia seguinte, que "dispõe sobre registro, posse e comercialização de armas de fogo e munição

# %%
import pandas as pd
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
hom = pd.read_csv('homicidios-por-armas-de-fogo.csv', sep=";")
hom
# Out:
#      cod nome  período  valor
# 0     15   PA     1996    349
# 1     25   PB     1996    275
# 2     26   PE     1996   2325
# 3     22   PI     1996     40
# 4     41   PR     1996    787
# 5     33   RJ     1996   6017
# 6     12   AC     1996     61
# 7     24   RN     1996    143
# 8     11   RO     1996    196
# 9     14   RR     1996     50
# 10    43   RS     1996    997
# 11    53   DF     1996    435
# 12    42   SC     1996    213
# 13    28   SE     1996    152
# 14    35   SP     1996   5365
# 15    23   CE     1996    351
# 16    29   BA     1996   1488
# 17    16   AP     1996     89
# 18    21   MA     1996    187
# 19    51   MT     1996    427
# 20    50   MS     1996    468
# 21    17   TO     1996     49
# 22    13   AM     1996    220
# 23    27   AL     1996    515
# 24    52   GO     1996    469
# 25    32   ES     1996    661
# 26    31   MG     1996    647
# 27    11   RO     1997    206
# 28    35   SP     1997   5377
# 29    12   AC     1997     55
# ...

# %%
hom.columns
# Out:
# Index(['cod', 'nome', 'período', 'valor'], dtype='object')

# %%
len(hom[hom['período'] == 2004])
# Out:
# 27

# %% [markdown]
# ### 27 estados da federação

# %%
hom_2004 = hom[hom['período'] == 2004]

# %%
sum(hom_2004['valor'])
# Out:
# 34187

# %%
# 34187 homididios registrados nas 27 fedrações no ano de 2004

# %%
hom_2004 = hom[hom['período'] == 2004]
hom_2005 = hom[hom['período'] == 2005]
hom_2006 = hom[hom['período'] == 2006]
hom_2007 = hom[hom['período'] == 2007]
hom_2008 = hom[hom['período'] == 2008]
hom_2009 = hom[hom['período'] == 2009]
hom_2010 = hom[hom['período'] == 2010]
hom_2011 = hom[hom['período'] == 2011]
hom_2012 = hom[hom['período'] == 2012]
hom_2013 = hom[hom['período'] == 2013]
hom_2014 = hom[hom['período'] == 2014]
hom_2015 = hom[hom['período'] == 2015]
hom_2016 = hom[hom['período'] == 2016]

# %%
hom_2016
# Out:
#      cod nome  período  valor
# 540   51   MT     2016    752
# 541   15   PA     2016   3048
# 542   25   PB     2016   1060
# 543   26   PE     2016   3475
# 544   22   PI     2016    440
# 545   41   PR     2016   2125
# 546   33   RJ     2016   4019
# 547   24   RN     2016   1569
# 548   11   RO     2016    465
# 549   14   RR     2016     72
# 550   43   RS     2016   2507
# 551   42   SC     2016    611
# 552   28   SE     2016   1259
# 553   35   SP     2016   2720
# 554   17   TO     2016    312
# 555   50   MS     2016    326
# 556   31   MG     2016   3321
# 557   21   MA     2016   1625
# 558   52   GO     2016   2143
# 559   32   ES     2016    968
# 560   53   DF     2016    516
# 561   23   CE     2016   2908
# 562   29   BA     2016   5449
# 563   16   AP     2016    222
# 564   13   AM     2016    791
# 565   27   AL     2016   1546
# 566   12   AC     2016    226

# %%
hom_values = [
    sum(hom_2004['valor']),
    sum(hom_2005['valor']),
    sum(hom_2006['valor']),
    sum(hom_2007['valor']),
    sum(hom_2008['valor']),
    sum(hom_2009['valor']),
    sum(hom_2010['valor']),
    sum(hom_2011['valor']),
    sum(hom_2012['valor']),
    sum(hom_2013['valor']),
    sum(hom_2014['valor']),
    sum(hom_2015['valor']),
    sum(hom_2016['valor'])
]
hom_year = [2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]

# %%
plt.plot(hom_year,hom_values)
plt.xlabel=("Numero de Homicídios")
plt.ylabel=("Ano")
plt.title("Homicídios por Armas de Fogo(2004 a 2016)")
plt.show()

# %%
plt.bar(hom_year,hom_values)
plt.title("Homicídios por Armas de Fogo(2004 a 2016)")
plt.show()
